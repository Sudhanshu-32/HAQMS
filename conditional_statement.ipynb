# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudhanshu-32/HAQMS/blob/main/conditional_statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# creating strings
s1='A'
s2="A"
s3='''A'''
s4="""A"""
s5=""

# %%
s1="sudhanshu"
print(s1[2])
print(s1[12])
# Out:
# d
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_851/4231382416.py in <cell line: 0>()
#       1 s1="sudhanshu"
#       2 print(s1[2])
# ----> 3 print(s1[12])
#
# IndexError: string index out of range

# %%
# indexing
s="python"
print(s[-1])
# Out:
# n

# %%
# slicing
s1="PYTHON"
print(s1[1:6:1])
print(s1[1:9:1])
s2="my name is sudhanshu"
print(s2[2:5])
print(s2[2:])
print(s2[:])
print(s2[:10])
print(s2[-2:-5])
print(s2[-5:-2])
# Out:
# YTHON
# YTHON
#  na
#  name is sudhanshu
# my name is sudhanshu
# my name is
#
# ans

# %%
s3="PYTHON"
print(s3[0:10])
print(s3[-len(s3):6])
print(s3[:len(s3)])
print(s3[6:-6])
print(s3[-6:6])
# Out:
# PYTHON
# PYTHON
# PYTHON
#
# PYTHON

# %%
# string operation
# 1.concantenation
s1="data"
s2="science"
final=s1+" "+s2
print(s1+s2)
print(final)
# 2.repetition
print(s1*2)
print(s2*4)
# membership
print("a" in s1)
print("m" in s1)
"k " in s2
# Out:
# datascience
# data science
# datadata
# sciencesciencesciencescience
# True
# False
# False

# %%
# string methods
text="python PROgram"
print(text.find("t"))
print(text.upper())
print(text.title())
print(text.lower())
print(text.capitalize())
print(text.swapcase())
print(text.index("RO"))
print(text.count("o"))
print(text.startswith("ing"))
print(text.endswith("ing"))
# Out:
# 2
# PYTHON PROGRAM
# Python Program
# python program
# Python program
# PYTHON proGRAM
# 8
# 1
# False
# False

# %%
name="sk"
salary="20k"
print(f"my name is {name} and my salary is {salary} .")
# Out:
# my name is sk and my salary is 20k.

# %%
# conditional statement
# 1. if
age=20
if age>=20:
  print("eligible")
# Out:
# eligible

# %%
marks=70
if marks>90:
  print("A")
if marks>80:
  print("B")
if marks>70:
  print("C")
if marks>60:
  print("D")
if marks>50:
  print("E")
# Out:
# D
# E

# %%
# utf code
print("\U0001F606")
# Out:
# 😆

# %%
# conditional statement with boolean value
if True:
  #or if 1:
  print("condition T")
if False:
  print ("condition F")

print(3<5)
# Out:
# condition T
# True

# %%
# comparison operator with if
user="admin"
if user=="admin":
  print("access")
# Out:
# access

# %%
# logical operator with if
# wap to find a person is eligible or not
age=int(input("enter the age:"))
salary=int(input("enter the salary:"))
if age>18 and salary>25000:
  print("eligible for loan")
# using or
m1=int(input("marks:"))
if m1>100 or m1<0:
  print("incorrect marks")
#using not
its_raining=False
if not its_raining:
  print("go outside")
# Out:
# enter the age:23
# enter the salary:45666
# eligible for loan
# marks:-23
# incorrect marks
# go outside

# %%
a=10
b=20
if a!=b:
  print("will print")
# Out:
# will print

# %%
# else statement
n=120
if n>120:
  print("eligible")
else:
  print("less than req")
# Out:
# less than req

# %%
# nested if
age=20
id=True
if age>18:
  if id:
    print("eligible for vote")
  else:
    print("no id")
else:
  print("not eligible for vote")
# Out:
# eligible for vote

# %%
# elif statement
#  wap for grade system
m1=int(input("enter the marks of sub 1:"))
m2=int(input("enter the marks of sub 2:"))
m3=int(input("enter the marks of sub 3:"))
m4=int(input("enter the marks of sub 4:"))
m5=int(input("enter the marks of sub 5:"))
sum=m1+m2+m3+m4+m5
avg=sum/5
if avg>90 and avg<100:
  print("The garde is : A")
elif avg>80 and avg<90:
  print("The garde is : B")
elif avg>70 and avg<80:
  print("The garde is : C")
elif avg>60 and avg<70:
  print("The garde is : D")
elif avg>50 and avg<60:
  print("The garde is : E")
else:
  print("student is fail")
# Out:
# enter the marks of sub 1:56
# enter the marks of sub 2:89
# enter the marks of sub 3:89
# enter the marks of sub 4:78
# enter the marks of sub 5:67
# The garde is : C

# %%
# wap to find day of week
day=int(input("enter the day number-1 to 7:"))
if day==1:
  print("Monday")
elif day==2:
  print("Tuewsday")
elif day==3:
  print("wednesday")
elif day==4:
  print("Thursday")
elif day==5:
  print("friday")
elif day==6:
  print("saturday")
elif day==7:
  print("sunday")
else:
  print("invalid input")
# Out:
# enter the day number-1 to 7:5
# friday

# %%
n1=100
n2=25
n3=12
if n1>n2 and n1>n3:
  print("n1 is greater")
elif n2>n1 and n2>n3:
  print("n2 is greater")
else:
  print("n3 is greater")
# Out:
# n1 is greater

# %%
n1=float(input("enter the number"))
if n1>0:
  print("positive")
elif n1==0:
  print("0")
else:
  print("negative")
# Out:
# enter the number-0
# 0

# %%
# wap to find bill amount according to unit used
unit=float(input("enter the unit "))
if unit>0 and unit <100:
  total_cost=unit*5
  print(total_cost)
elif unit>=100 and unit<200:
   total_cost=unit*10
   print(total_cost)

elif unit>=200 :
   total_cost=unit*15
   print(total_cost)
else:
  print("invalid input")
# Out:
# enter the unit 200
# 3000.0

# %%
# wap for an ATM withdrawal system that valiadte the withdrawal amount,checks the available balance and displays the transaction status using conditional statement.
Balance=float(input("enter the account balance:"))
Amount=float(input("enter the amount to withdraw:"))
if Amount<= 0:
  print("invalid amount")
elif Amount>Balance:
  print("insufficient balance")
elif Amount %100 !=0:
  print("enter the multiple of 100")
else:
  Balance=Balance-Amount
  print(f"remaining balance is {Balance}")
  print("transaction successfull")
# Out:
# enter the account balance:33400
# enter the amount to withdraw:0
# invalid amount

# %%
# wap to find leap year
year=int(input("enter the year:"))
if (year%4==0 and year%100!=0) or (year%400==0):
      print("leap year")
else:
      print("not leap year")
# Out:
# enter the year:2400
# leap year
